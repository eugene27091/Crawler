# %% [markdown]
# <a href="https://colab.research.google.com/github/eugene27091/Crawler/blob/master/time_dogpre2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import font_manager
# !apt install fonts-nanum

plt.rcParams['figure.figsize'] = [20, 50]

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('/content/drive/MyDrive/dogPre/DogPre_less_than_6.xlsx')

# df.sort_values(['review_num'],ascending=True)
# df.review_num.sort_values()
# df.sort_values(by='review_num' ,ascending=False)

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Unnamed: 0.1      int64
# num               int64
# item             object
# date             object
# star              int64
# breed            object
# age              object
# document         object
# token            object
# review_length     int64
# dtype: object

# %%
df_clock = df[['item','date','star']]
df_clock
df_clock['date'] = pd.to_datetime(df_clock['date'])
df_clock['num'] = 1
df_clock.to_excel("/content/drive/MyDrive/dogPre/df_clock.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df_clock['brand'] = df_clock.item.str.split(' ').str[0]
df_clock
# df_clock.to_excel("/content/drive/MyDrive/dogPre/df_clock_brand.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
brand_no = df['brand'].value_counts()
brand_no
# Out:
# 네츄럴코어     49802
# 시저        20936
# now        7780
# 아침애        6508
# 뉴트리나       6403
# ANF        5616
# 더독         4460
# 오리젠        2529
# 아카나        1808
# 내추럴발란스     1662
# 로얄캐닌       1054
# 제니스         769
# 지위픽         388
# 데이스포        355
# 도비          298
# 펫츠프라임       180
# 올가밀         179
# 퓨리나         176
# 굿프랜드        118
# 하림펫푸드       116
# go!          85
# 위시본          60
# 퓨어비타         59
# 힐스           49
# 한끼뚝딱         41
# 네이처스         30
# 카루           30
# 앱솔루트         30
# 워프           30
# HALO         30
# 아스쿠          24
# [1+1]        20
# 도그랑          17
# Name: brand, dtype: int64

# %%
df_clock.sort_values(by='brand',ascending=False)
df_1 = df_clock[df_clock['brand'] =='네츄럴코어']
df_2 = df_clock[df_clock['brand'] =='시저']
df_3 = df_clock[df_clock['brand'] =='now']
df_4 = df_clock[df_clock['brand'] =='아침애']
df_5 = df_clock[df_clock['brand'] =='뉴트리나']
df_6 = df_clock[df_clock['brand'] =='ANF']
df_7 = df_clock[df_clock['brand'] =='더독']
df_8 = df_clock[df_clock['brand'] =='오리젠']
df_9 = df_clock[df_clock['brand'] =='아카나']
df_10 = df_clock[df_clock['brand'] =='내추럴발란스']

frames = [df_1, df_2, df_3,df_4, df_5, df_6,df_7, df_8, df_9,df_10]
top10 = pd.concat(frames)
top10
top10.to_excel("/content/drive/MyDrive/dogPre/top10.xlsx")

# %%
df_clock.dtypes
df_clock.set_index('date')
# Out:
#                                     item  star  num  brand
# date
# 2015-03-20  네츄럴코어 홀리스틱 베네 M32 멀티프로테인 6kg     5    1  네츄럴코어
# 2015-07-09  네츄럴코어 홀리스틱 베네 M32 멀티프로테인 6kg     5    1  네츄럴코어
# 2014-04-24  네츄럴코어 홀리스틱 베네 M32 멀티프로테인 6kg     5    1  네츄럴코어
# 2019-04-26  네츄럴코어 홀리스틱 베네 M32 멀티프로테인 6kg     5    1  네츄럴코어
# 2014-02-11  네츄럴코어 홀리스틱 베네 M32 멀티프로테인 6kg     5    1  네츄럴코어
# ...                                  ...   ...  ...    ...
# 2017-10-19           굿프랜드 스페셜서퍼 닭고기 285g     5    1   굿프랜드
# 2017-10-12           굿프랜드 스페셜서퍼 닭고기 285g     5    1   굿프랜드
# 2017-10-12           굿프랜드 스페셜서퍼 닭고기 285g     5    1   굿프랜드
# 2017-09-16           굿프랜드 스페셜서퍼 닭고기 285g     5    1   굿프랜드
# 2017-09-11           굿프랜드 스페셜서퍼 닭고기 285g     5    1   굿프랜드
#
# [111642 rows x 4 columns]

# %%
grouped = top10.groupby('brand')
print(grouped)

# %%
for i in grouped:
    print(type(i))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
for key, group in grouped:
    print("* key", key)
    group_sum = group.resample('m', on='date')['num'].sum()
    print(group_sum)
# Out:
# * key ANF
# date
# 2009-01-31     23
# 2009-02-28      8
# 2009-03-31     11
# 2009-04-30     22
# 2009-05-31     18
#              ...
# 2021-04-30    107
# 2021-05-31     93
# 2021-06-30    114
# 2021-07-31     93
# 2021-08-31     52
# Freq: M, Name: num, Length: 152, dtype: int64
# * key now
# date
# 2015-04-30     1
# 2015-05-31     4
# 2015-06-30    10
# 2015-07-31    20
# 2015-08-31    65
#               ..
# 2021-04-30    87
# 2021-05-31    72
# 2021-06-30    65
# 2021-07-31    29
# 2021-08-31    17
# Freq: M, Name: num, Length: 77, dtype: int64
# * key 내추럴발란스
# date
# 2017-03-31      2
# 2017-04-30      0
# 2017-05-31      0
# 2017-06-30      6
# 2017-07-31      4
# 2017-08-31      7
# 2017-09-30      6
# 2017-10-31     10
# 2017-11-30      5
# 2017-12-31      7
# 2018-01-31      8
# 2018-02-28     14
# 2018-03-31     22
# 2018-04-30     31
# 2018-05-31     15
# 2018-06-30     25
# 2018-07-31     23
# 2018-08-31     13
# 2018-09-30     27
# 2018-10-31     32
# ...

# %%
df_clock.set_index('date')
# group_sum = df_clock.resample('m', on='date')['num'].sum()

for key, group in grouped:
    print("* key", key)
    group_sum.plot(kind='line')
    plt.show()
# Out:
# * key ANF
# * key now
# * key 내추럴발란스
# * key 네츄럴코어
# * key 뉴트리나
# * key 더독
# * key 시저
# * key 아침애
# * key 아카나
# * key 오리젠

# %%
# star_1and2 = df[df.star == 1 ]
# star_1and2
# star_1and2.to_excel('/content/drive/MyDrive/puppy/star_1,2,3.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-d1ed005f6dad> in <module>()
# ----> 1 star_1and2 = df[df.star == 1 or 2 or 3 ]
#       2 star_1and2
#       3 star_1and2.to_excel('/content/drive/MyDrive/puppy/star_1,2,3.xlsx')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1328     def __nonzero__(self):
#    1329         raise ValueError(
# -> 1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1332         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
product.groupby(by='item')
